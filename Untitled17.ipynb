# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import scipy.stats as stats
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import PowerTransformer

# %%
df =pd.read_csv(r"C:\Users\USER\OneDrive\Documents\concrete_data.csv")
df
# Out:
#     Cement  BlastFurnaceSlag  FlyAsh  Water  Superplasticizer  \
# 0    540.0               0.0       0    162               2.5
# 1    540.0               0.0       0    162               2.5
# 2    332.5             142.5       0    228               0.0
# 3    332.5             142.5       0    228               0.0
# 4    198.6             132.4       0    192               0.0
# 5    266.0             114.0       0    228               0.0
# 6    380.0              95.0       0    228               0.0
# 7    380.0              95.0       0    228               0.0
# 8    475.0               0.0       0    228               0.0
# 9    475.0               0.0       0    228               0.0
# 10   198.6             132.4       0    192               0.0
# 11   198.6             132.4       0    192               0.0
# 12   266.0             114.0       0    228               0.0
# 13   380.0              95.0       0    228               0.0
# ...

# %%
df.shape , df.isnull().sum()
# Out:
# ((15, 9),
#  Cement              0
#  BlastFurnaceSlag    0
#  FlyAsh              0
#  Water               0
#  Superplasticizer    0
#  CoarseAggregate     0
#  FineAggregate       0
#  Age                 0
#  ConcreteStrength    0
#  dtype: int64,
#     Cement  BlastFurnaceSlag  FlyAsh  Water  Superplasticizer  CoarseAggregate  \
#  0   540.0               0.0       0    162               2.5           1040.0
#  1   540.0               0.0       0    162               2.5           1055.0
#  2   332.5             142.5       0    228               0.0            932.0
#  3   332.5             142.5       0    228               0.0            932.0
#  4   198.6             132.4       0    192               0.0            978.4
#
#     FineAggregate  Age  ConcreteStrength
#  0          676.0   28             79.99
#  1          676.0   28             61.89
#  2          594.0  270             40.27
#  3          594.0  365             41.05
# ...

# %%
x = df.drop(columns=['ConcreteStrength'])
y= df.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# -2.435855989193392

# %%
for col in x_train.columns:
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    sns.distplot(x_train[col])
    plt.title(col)
    plt.subplot(122)
    stats.probplot(x_train[col],dist='norm',plot=plt)
    plt.title(col)

    plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_32024\3494412538.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x_train[col])
# C:\Users\USER\AppData\Local\Temp\ipykernel_32024\3494412538.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x_train[col])
# ...

# %%
    

non_cons_cols =x_train.columns[x_train.nunique()>1]

x_train_nc = x_train[non_cons_cols]
x_test_nc = x_test[non_cons_cols]



pt = PowerTransformer(method='box-cox')



x_train_transformed = pt.fit_transform(x_train_nc+0.000001)
x_test_transformed = pt.transform(x_test_nc+0.000001)
pd.DataFrame({'cols':x_train_nc.columns,'box_cox_lambdas':pt.lambdas_})
# Out:
#                cols  box_cox_lambdas
# 0            Cement         0.010332
# 1  BlastFurnaceSlag         0.191896
# 2             Water         5.783489
# 3  Superplasticizer        -0.400698
# 4   CoarseAggregate       -20.085774
# 5     FineAggregate        -3.697907
# 6               Age         0.132227

# %%
lr=LinearRegression()
lr.fit(x_train_transformed,y_train)
y_pred=lr.predict(x_test_transformed)
r2_score(y_test,y_pred)
# Out:
# -0.0119092139991821

# %%
# yeo-jhonson 
pt1=PowerTransformer()

x_train_transformed2=pt1.fit_transform(x_train_nc)
x_test_transformed2 = pt1.transform(x_test_nc)

lr = LinearRegression()
lr.fit(x_train_transformed2,y_train)

y_pred3 = lr.predict(x_test_transformed2)

print(r2_score(y_test,y_pred3))
pd.DataFrame({'cols':x_train_nc.columns,'Yeo_Jhonson_lambdas':pt1.lambdas_})
# Out:
# 0.2518753964279308
#                cols  Yeo_Jhonson_lambdas
# 0            Cement             0.008093
# 1  BlastFurnaceSlag             0.692391
# 2             Water             5.811421
# 3  Superplasticizer            -4.711985
# 4   CoarseAggregate            -4.399205
# 5     FineAggregate            -3.679896
# 6               Age             0.126147

# %%
x_train_transformed2 = pd.DataFrame(
    x_train_transformed2,
    columns=x_train_nc.columns
)



for col in x_train_transformed2.columns:
   plt.figure(figsize=(14,4))
   plt.subplot(121)
   sns.distplot(x_train_nc[col])
   plt.subplot(122)
   sns.distplot(x_train_transformed2[col])
   plt.title(col)
   plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_32024\1995952132.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x_train_nc[col])
# C:\Users\USER\AppData\Local\Temp\ipykernel_32024\1995952132.py:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
pd.DataFrame({'cols':x_train_nc.columns,'box_cox_lambdas':pt.lambdas_,'Yeo_Johnson_lambdas':pt1.lambdas_})
# Out:
#                cols  box_cox_lambdas  Yeo_Johnson_lambdas
# 0            Cement         0.010332             0.008093
# 1  BlastFurnaceSlag         0.191896             0.692391
# 2             Water         5.783489             5.811421
# 3  Superplasticizer        -0.400698            -4.711985
# 4   CoarseAggregate       -20.085774            -4.399205
# 5     FineAggregate        -3.697907            -3.679896
# 6               Age         0.132227             0.126147
