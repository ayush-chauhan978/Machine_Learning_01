# %%
import numpy as np
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# %%
df = pd.read_csv(r"C:\Users\USER\.ipynb_checkpoints\data_science.csv")
df.head()
# Out:
#    Job_ID        Job_Role Company_Size  Experience_Years Education_Level  \
# 0       1  Data Scientist        Large               3.0         Masters
# 1       2     ML Engineer       Medium               NaN       Bachelors
# 2       3    Data Analyst        Small               2.0       Bachelors
# 3       4     AI Engineer        Large               NaN             PhD
# 4       5  Data Scientist       Medium               4.0         Masters
#
#     Location  Salary_LPA Remote  Skills_Count
# 0  Bangalore          12    Yes           6.0
# 1  Hyderabad          15     No           NaN
# 2      Delhi           6    Yes           NaN
# 3       Pune          20     No           9.0
# 4     Mumbai          14    Yes           NaN

# %%
x = df.drop(columns=['Salary_LPA'])
y = df['Salary_LPA']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train['Skills_Count_0'] = x_train['Skills_Count'].fillna(0)
x_train['Experience_Years_0']= x_train['Experience_Years'].fillna(0)
x_train['Skills_Count_-1'] = x_train['Skills_Count'].fillna(-1)

# %%
x_train['Skills_Count'].var()
# Out:
# np.float64(7.28234398782344)

# %%
x_train['Skills_Count_0'].var()
# Out:
# np.float64(10.491139240506328)

# %%
x_train['Skills_Count_-1'].var()
# Out:
# np.float64(11.688449367088605)
