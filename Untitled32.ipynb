# %%
import numpy as np
import pandas as pd

from sklearn.linear_model import LinearRegression

# %%
df = np.round(pd.read_csv(r"C:\Users\USER\OneDrive\Documents\50-start.csv"))
np.random.seed(9)
df = df.sample(5)
df
# Out:
#     R&D Spend  Administration  Marketing Spend  Profit
# 4    142108.0         91391.0         366168.0  166188
# 19    86419.0        153514.0              0.0  122777
# 9    123335.0        108679.0         304982.0  149760
# 13    91992.0        135495.0         252664.0  134307
# 11   100671.0         91791.0         249744.0  144259

# %%
df = df.iloc[:,0:-1]
df
# Out:
#     R&D Spend  Administration  Marketing Spend
# 4    142108.0         91391.0         366168.0
# 19    86419.0        153514.0              0.0
# 9    123335.0        108679.0         304982.0
# 13    91992.0        135495.0         252664.0
# 11   100671.0         91791.0         249744.0

# %%
df.iloc[1,0] = np.nan
df.iloc[3,1]= np.nan
df.iloc[-1,-1] = np.nan

# %%
df.head()
# Out:
#     R&D Spend  Administration  Marketing Spend
# 4    142108.0         91391.0         366168.0
# 19        NaN        153514.0              0.0
# 9    123335.0        108679.0         304982.0
# 13    91992.0             NaN         252664.0
# 11   100671.0         91791.0              NaN

# %%
df0 = pd.DataFrame()

df0['R&D Spend'] = df['R&D Spend'].fillna(df['R&D Spend'].mean())
df0['Administration'] = df['Administration'].fillna(df['Administration'].mean())
df0['Marketing Spend'] = df['Marketing Spend'].fillna(df['Marketing Spend'].mean())

# %%
df0
# Out:
#     R&D Spend  Administration  Marketing Spend
# 4    142108.0        91391.00         366168.0
# 19   114526.5       153514.00              0.0
# 9    123335.0       108679.00         304982.0
# 13    91992.0       111343.75         252664.0
# 11   100671.0        91791.00         230953.5

# %%
df1 = df0.copy()

df1.iloc[1,0] = np.nan
df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 4    142108.0        91391.00         366168.0
# 19        NaN       153514.00              0.0
# 9    123335.0       108679.00         304982.0
# 13    91992.0       111343.75         252664.0
# 11   100671.0        91791.00         230953.5

# %%
x = df1.iloc[[0,2,3,4],1:3]
x
# Out:
#     Administration  Marketing Spend
# 4         91391.00         366168.0
# 9        108679.00         304982.0
# 13       111343.75         252664.0
# 11        91791.00         230953.5

# %%
y = df.iloc[[0,2,3,4],0]
y
# Out:
# 4     142108.0
# 9     123335.0
# 13     91992.0
# 11    100671.0
# Name: R&D Spend, dtype: float64

# %%
lr = LinearRegression()
lr.fit(x,y)
lr.predict(df1.iloc[1,1:].values.reshape(1,2))
# Out:
# C:\Users\USER\ml_env\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-5913.81932123])

# %%
df1.iloc[1,0]=5913.81932123

# %%
df1
# Out:
#         R&D Spend  Administration  Marketing Spend
# 4   142108.000000        91391.00         366168.0
# 19    5913.819321       153514.00              0.0
# 9   123335.000000       108679.00         304982.0
# 13   91992.000000       111343.75         252664.0
# 11  100671.000000        91791.00         230953.5

# %%
df1.iloc[3,1] = np.nan

# %%
df1
# Out:
#         R&D Spend  Administration  Marketing Spend
# 4   142108.000000         91391.0         366168.0
# 19    5913.819321        153514.0              0.0
# 9   123335.000000        108679.0         304982.0
# 13   91992.000000             NaN         252664.0
# 11  100671.000000         91791.0         230953.5

# %%
x = df1.iloc[[0,1,2,4],[0,2]]
x
# Out:
#         R&D Spend  Marketing Spend
# 4   142108.000000         366168.0
# 19    5913.819321              0.0
# 9   123335.000000         304982.0
# 11  100671.000000         230953.5

# %%
y = df.iloc[[0,1,2,4],1]
y
# Out:
# 4      91391.0
# 19    153514.0
# 9     108679.0
# 11     91791.0
# Name: Administration, dtype: float64

# %%
lr = LinearRegression()
lr.fit(x,y)
lr.predict(df1.iloc[3,[0,2]].values.reshape(1,2))
# Out:
# C:\Users\USER\ml_env\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([134006.87851458])

# %%
df1.iloc[3,1] = 134006.87851458
df1
# Out:
#         R&D Spend  Administration  Marketing Spend
# 4   142108.000000    91391.000000         366168.0
# 19    5913.819321   153514.000000              0.0
# 9   123335.000000   108679.000000         304982.0
# 13   91992.000000   134006.878515         252664.0
# 11  100671.000000    91791.000000         230953.5

# %%
df1
# Out:
#         R&D Spend  Administration  Marketing Spend
# 4   142108.000000    91391.000000         366168.0
# 19    5913.819321   153514.000000              0.0
# 9   123335.000000   108679.000000         304982.0
# 13   91992.000000   134006.878515         252664.0
# 11  100671.000000    91791.000000         230953.5

# %%
df1 - df0
# Out:
#         R&D Spend  Administration  Marketing Spend
# 4        0.000000        0.000000              0.0
# 19 -108612.680679        0.000000              0.0
# 9        0.000000        0.000000              0.0
# 13       0.000000    22663.128515              0.0
# 11       0.000000        0.000000              0.0
