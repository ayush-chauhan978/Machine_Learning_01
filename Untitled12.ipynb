# %%
# standardization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\USER\ayush_1\a.csv")
df
# Out:
#     ID     Name  Score
# 0    1    Alice     85
# 1    2      Bob     78
# 2    3  Charlie     92
# 3    4    David     88
# 4    5     Emma     90
# 5    6    Frank     75
# 6    7    Grace     95
# 7    8    Helen     82
# 8    9      Ian     79
# 9   10     Jack     91
# 10  11     Kate     87
# 11  12      Leo     80
# 12  13      Mia     89
# 13  14     Nina     93
# 14  15    Oscar     76

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.drop('Name',axis=1),df['Name'],test_size=0.3,random_state=0)
X_train.shape,X_test.shape
# Out:
# ((10, 2), (5, 2))

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
scaler.mean_
# Out:
# array([ 7.7, 86.1])

# %%
X_train_scaled = pd.DataFrame(X_train_scaled , columns = X_train.columns)
x_test_scaled =pd.DataFrame(X_test_scaled , columns = X_test.columns)

# %%
np.round(X_train_scaled.describe(),1)
# Out:
#          ID  Score
# count  10.0   10.0
# mean   -0.0    0.0
# std     1.1    1.1
# min    -1.5   -2.1
# 25%    -0.8   -0.6
# 50%    -0.2    0.3
# 75%     0.9    0.7
# max     1.5    1.3

# %%
X_train_scaled
# Out:
#          ID     Score
# 0 -0.622543  0.725589
# 1 -1.083686  1.097686
# 2  1.452600  1.283735
# 3  0.760886  0.167444
# 4  0.069171 -0.762799
# 5  0.991457 -1.134896
# 6 -0.853115  0.353492
# 7 -1.544829 -0.204653
# 8 -0.391972 -2.065139
# 9  1.222029  0.539541
