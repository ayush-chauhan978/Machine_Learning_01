# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\USER\Downloads\placement_dataset.csv")

# %%
df['CGPA'].describe()
# Out:
# count    50.000000
# mean      6.819200
# std       0.746879
# min       5.430000
# 25%       6.307500
# 50%       6.810000
# 75%       7.265000
# max       8.480000
# Name: CGPA, dtype: float64

# %%
import seaborn as sns

# %%
sns.distplot(df['CGPA'])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2360\3833812877.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['CGPA'])
# <Axes: xlabel='CGPA', ylabel='Density'>

# %%
sns.boxplot(df['CGPA'])
# Out:
# <Axes: ylabel='CGPA'>

# %%
upper_limit =df['CGPA'].quantile(.95)
lower_limit = df['CGPA'].quantile(0.05)# uppr and lower limit should be symmetrical

# %%
new_df=df[(df['CGPA']<=8.1975) &  (df['CGPA']>=5.6035)]

# %%
new_df['CGPA'].describe()
# Out:
# count    44.000000
# mean      6.807045
# std       0.595907
# min       5.620000
# 25%       6.495000
# 50%       6.810000
# 75%       7.205000
# max       8.170000
# Name: CGPA, dtype: float64

# %%
sns.distplot(df['CGPA'])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2360\3833812877.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['CGPA'])
# <Axes: xlabel='CGPA', ylabel='Density'>

# %%
# capping-- winsorization
np.where(df['CGPA']>= upper_limit,
         upper_limit,
         np.where(df['CGPA']<= lower_limit,
                  lower_limit,
                  df['CGPA']
                 )
        )
# Out:
# array([7.4   , 6.89  , 7.52  , 8.1975, 6.81  , 6.81  , 8.1975, 7.61  ,
#        6.62  , 7.43  , 6.63  , 6.63  , 7.19  , 5.6035, 5.62  , 6.55  ,
#        6.19  , 7.25  , 6.27  , 5.87  , 8.17  , 6.82  , 7.05  , 5.86  ,
#        6.56  , 7.09  , 6.08  , 7.3   , 6.52  , 6.77  , 6.52  , 8.1975,
#        6.99  , 6.15  , 7.66  , 6.02  , 7.17  , 5.6035, 5.94  , 7.16  ,
#        7.59  , 7.14  , 6.91  , 6.76  , 5.82  , 6.42  , 6.63  , 7.85  ,
#        7.27  , 5.6035])
