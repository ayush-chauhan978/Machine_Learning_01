# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\USER\OneDrive\Documents\customer.csv")
df
# Out:
#       Customer_Name  Age  Gender Customer_Type    Reviews      Education
# 0       Amit Sharma   25    Male       Regular       Good       Graduate
# 1        Neha Verma   22  Female           New    Average  Undergraduate
# 2       Rahul Singh   30    Male       Premium  Excellent   Postgraduate
# 3       Pooja Mehta   28  Female       Regular       Good       Graduate
# 4       Rohit Kumar   35    Male       Premium  Excellent   Postgraduate
# 5      Anjali Gupta   24  Female           New    Average       Graduate
# 6        Vikas Jain   40    Male       Regular       Good       Graduate
# 7       Sneha Patel   27  Female       Premium  Excellent   Postgraduate
# 8    Arjun Malhotra   32    Male       Regular       Good       Graduate
# 9        Kavita Rao   29  Female           New    Average       Graduate
# 10     Suresh Yadav   45    Male       Regular       Poor    High School
# 11      Riya Kapoor   21  Female           New       Good  Undergraduate
# ...

# %%
df['Gender'].value_counts()
df['Education'].nunique()
# Out:
# 4

# %%
#OHE using pandas 
pd.get_dummies(df,columns=['Gender','Reviews'],dtype=int)
# Out:
#       Customer_Name  Age Customer_Type      Education  Gender_Female  \
# 0       Amit Sharma   25       Regular       Graduate              0
# 1        Neha Verma   22           New  Undergraduate              1
# 2       Rahul Singh   30       Premium   Postgraduate              0
# 3       Pooja Mehta   28       Regular       Graduate              1
# 4       Rohit Kumar   35       Premium   Postgraduate              0
# 5      Anjali Gupta   24           New       Graduate              1
# 6        Vikas Jain   40       Regular       Graduate              0
# 7       Sneha Patel   27       Premium   Postgraduate              1
# 8    Arjun Malhotra   32       Regular       Graduate              0
# 9        Kavita Rao   29           New       Graduate              1
# 10     Suresh Yadav   45       Regular    High School              0
# 11      Riya Kapoor   21           New  Undergraduate              1
# 12     Manoj Mishra   38       Premium   Postgraduate              0
# ...

# %%
pd.get_dummies(df,columns=['Gender','Reviews'],dtype=int,drop_first=True)
# pandas don"t remember where it has which column
# Out:
#       Customer_Name  Age Customer_Type      Education  Gender_Male  \
# 0       Amit Sharma   25       Regular       Graduate            1
# 1        Neha Verma   22           New  Undergraduate            0
# 2       Rahul Singh   30       Premium   Postgraduate            1
# 3       Pooja Mehta   28       Regular       Graduate            0
# 4       Rohit Kumar   35       Premium   Postgraduate            1
# 5      Anjali Gupta   24           New       Graduate            0
# 6        Vikas Jain   40       Regular       Graduate            1
# 7       Sneha Patel   27       Premium   Postgraduate            0
# 8    Arjun Malhotra   32       Regular       Graduate            1
# 9        Kavita Rao   29           New       Graduate            0
# 10     Suresh Yadav   45       Regular    High School            1
# 11      Riya Kapoor   21           New  Undergraduate            0
# 12     Manoj Mishra   38       Premium   Postgraduate            1
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df.iloc[:,[0,1,2,4,5]],df.iloc[:,3],test_size=0.2,random_state=0)

# %%
x_train
# Out:
#       Customer_Name  Age  Gender    Reviews      Education
# 10     Suresh Yadav   45    Male       Poor    High School
# 17       Meena Iyer   42  Female       Good       Graduate
# 6        Vikas Jain   40    Male       Good       Graduate
# 13  Nisha Choudhary   26  Female       Good       Graduate
# 4       Rohit Kumar   35    Male  Excellent   Postgraduate
# 2       Rahul Singh   30    Male  Excellent   Postgraduate
# 5      Anjali Gupta   24  Female    Average       Graduate
# 14     Deepak Verma   34    Male    Average       Graduate
# 9        Kavita Rao   29  Female    Average       Graduate
# 7       Sneha Patel   27  Female  Excellent   Postgraduate
# 16     Karan Khanna   31    Male  Excellent   Postgraduate
# 11      Riya Kapoor   21  Female       Good  Undergraduate
# 3       Pooja Mehta   28  Female       Good       Graduate
# 0       Amit Sharma   25    Male       Good       Graduate
# 15     Priya Saxena   23  Female       Good  Undergraduate
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder(drop='first')

# %%
x_new=ohe.fit_transform(x_train[['Reviews','Education']]).toarray()
x_new.shape
# Out:
# (16, 6)

# %%
x_test_new=ohe.transform(x_test[['Reviews','Education']]).toarray()
x_test_new.shape
# Out:
# (4, 6)

# %%
np.hstack((x_train[['Customer_Name','Age']].values,x_new)).shape
# Out:
# (16, 8)

# %%
counts=df[
