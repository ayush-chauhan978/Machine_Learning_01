# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\USER\Downloads\placement_dataset.csv")
df
# Out:
#     CGPA  Exam_Marks  Placed
# 0   7.40       52.28       1
# 1   6.89       74.31       1
# 2   7.52       51.16       1
# 3   8.22      100.00       1
# 4   6.81       72.19       1
# 5   6.81       53.32       1
# 6   8.26       50.08       1
# 7   7.61       75.35       1
# 8   6.62       68.41       1
# 9   7.43       69.58       1
# 10  6.63       72.13       1
# 11  6.63       51.15       0
# 12  7.19       56.66       1
# 13  5.47       51.85       0
# 14  5.62       79.83       1
# 15  6.55       64.64       1
# 16  6.19       56.03       0
# 17  7.25       50.99       1
# 18  6.27       55.59       0
# 19  5.87       55.90       0
# 20  8.17       69.62       1
# 21  6.82       65.22       1
# 22  7.05       82.73       1
# 23  5.86       59.59       0
# 24  6.56       51.91       0
# 25  7.09       68.74       1
# 26  6.08       71.46       1
# 27  7.30       62.36       1
# 28  6.52       72.11       1
# 29  6.77       60.21       1
# 30  6.52       61.10       1
# ...

# %%
df.shape
# Out:
# (50, 3)

# %%
df.sample(5)
# Out:
#     CGPA  Exam_Marks  Placed
# 13  5.47       51.85       0
# 34  7.66       50.48       1
# 35  6.02       65.18       1
# 27  7.30       62.36       1
# 10  6.63       72.13       1

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['CGPA'])

plt.subplot(1,2,2)
sns.distplot(df['Exam_Marks'])

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_22192\244997435.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['CGPA'])
# C:\Users\USER\AppData\Local\Temp\ipykernel_22192\244997435.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Exam_Marks'])

# %%
df['Exam_Marks'].describe()
# Out:
# count     50.000000
# mean      63.425800
# std       11.813966
# min       50.080000
# 25%       53.465000
# 50%       60.435000
# 75%       71.377500
# max      100.000000
# Name: Exam_Marks, dtype: float64

# %%
sns.boxplot(df['Exam_Marks'])
# Out:
# <Axes: ylabel='Exam_Marks'>

# %%
percentile25 = df['Exam_Marks'].quantile(0.25)
percentile75 = df['Exam_Marks'].quantile(0.75)

# %%
percentile25
# Out:
# np.float64(53.465)

# %%
iqr = percentile75 - percentile25
iqr
# Out:
# np.float64(17.912499999999994)

# %%
upper_limit = percentile75 +1.5* iqr
lower_limit = percentile25 - 1.5* iqr

# %%
df[df['Exam_Marks']> upper_limit]
# Out:
#    CGPA  Exam_Marks  Placed
# 3  8.22       100.0       1

# %%
#now can done trimming and capping
