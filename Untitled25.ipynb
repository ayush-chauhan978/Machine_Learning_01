# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# %%
df =pd.read_csv(r"C:\Users\USER\.ipynb_checkpoints\data_science_2.csv")

# %%
df.head()
# Out:
#    Job_ID        Job_Role Company_Size  Experience_Years Education_Level  \
# 0       1  Data Scientist        Large               3.0         Masters
# 1       2     ML Engineer       Medium               NaN       Bachelors
# 2       3    Data Analyst        Small               2.0       Bachelors
# 3       4     AI Engineer        Large               NaN             PhD
# 4       5  Data Scientist       Medium               4.0         Masters
#
#     Location  Salary_LPA Remote  Skills_Count
# 0  Bangalore          12    Yes           6.0
# 1  Hyderabad          15     No           NaN
# 2      Delhi           6    Yes           NaN
# 3       Pune          20     No           9.0
# 4     Mumbai          14    Yes           NaN

# %%
df.isnull().mean()
# Out:
# Job_ID              0.00
# Job_Role            0.00
# Company_Size        0.00
# Experience_Years    0.08
# Education_Level     0.07
# Location            0.04
# Salary_LPA          0.00
# Remote              0.00
# Skills_Count        0.11
# dtype: float64

# %%
x =df.drop(columns=['Salary_LPA'])
y = df['Salary_LPA']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.isnull().mean()
# Out:
# Job_ID              0.0000
# Job_Role            0.0000
# Company_Size        0.0000
# Experience_Years    0.1000
# Education_Level     0.0500
# Location            0.0375
# Remote              0.0000
# Skills_Count        0.0875
# dtype: float64

# %%
mean_sc = x_train['Skills_Count'].mean()
median_sc = x_train['Skills_Count'].median()

mean_exp = x_train['Experience_Years'].mean()
median_exp = x_train['Experience_Years'].median()

# %%
x_train['mean_sc'] = x_train['Skills_Count'].fillna(mean_sc)
x_train['median_sc']= x_train['Skills_Count'].fillna(median_sc)

x_train
# Out:
#     Job_ID        Job_Role Company_Size  Experience_Years Education_Level  \
# 43      44     AI Engineer       Medium               5.0             PhD
# 62      63    Data Analyst        Large               3.0             NaN
# 3        4     AI Engineer        Large               NaN             PhD
# 71      72     ML Engineer        Large               6.0         Masters
# 45      46  Data Scientist        Small               2.0             NaN
# ..     ...             ...          ...               ...             ...
# 96      97     ML Engineer        Small               1.0       Bachelors
# 67      68    Data Analyst       Medium               3.0         Masters
# 64      65   Data Engineer       Medium               5.0         Masters
# 47      48    Data Analyst        Large               3.0       Bachelors
# 44      45   Data Engineer        Large               7.0         Masters
#
#      Location Remote  Skills_Count  mean_sc  median_sc
# ...

# %%
x_train['Skills_Count'].var()
# Out:
# np.float64(7.28234398782344)

# %%
x_train['mean_sc'].var()
# Out:
# np.float64(6.637073001560603)

# %%
x_train['median_sc'].var()
# Out:
# np.float64(6.637816455696203)

# %%
x_train[['Skills_Count','mean_sc','median_sc']].boxplot()
# Out:
# <Axes: >

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
imputer1 = SimpleImputer(strategy='median')
imputer2 = SimpleImputer(strategy='mean')

# %%
trf = ColumnTransformer([
    ('imputer1',imputer1,['Skills_Count']),
    ('imputer2',imputer2,['Experience_Years'])
],remainder='passthrough')

# %%
trf.fit(x_train)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('imputer1', SimpleImputer(strategy='median'),
#                                  ['Skills_Count']),
#                                 ('imputer2', SimpleImputer(),
#                                  ['Experience_Years'])])

# %%
trf.named_transformers_['imputer1'].statistics_
# Out:
# array([7.])

# %%
trf.named_transformers_['imputer2'].statistics_
# Out:
# array([4.06944444])

# %%
x_train = trf.transform(x_train)
x_test = trf.transform(x_test)

# %%
a=pd.DataFrame(x_train)
a
# Out:
#        0         1   2               3       4          5          6    7
# 0   10.0       5.0  44     AI Engineer  Medium        PhD  Bangalore  Yes
# 1    5.0       3.0  63    Data Analyst   Large        NaN     Mumbai   No
# 2    9.0  4.069444   4     AI Engineer   Large        PhD       Pune   No
# 3    9.0       6.0  72     ML Engineer   Large    Masters     Mumbai  Yes
# 4    5.0       2.0  46  Data Scientist   Small        NaN     Mumbai  Yes
# ..   ...       ...  ..             ...     ...        ...        ...  ...
# 75   4.0       1.0  97     ML Engineer   Small  Bachelors      Delhi   No
# 76   4.0       3.0  68    Data Analyst  Medium    Masters       Pune  Yes
# 77   8.0       5.0  65   Data Engineer  Medium    Masters  Hyderabad   No
# 78   5.0       3.0  48    Data Analyst   Large  Bachelors  Bangalore  Yes
# 79   9.0       7.0  45   Data Engineer   Large    Masters      Delhi   No
#
# [80 rows x 8 columns]
