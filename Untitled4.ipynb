# %%
import pandas as pd
import requests

# %%
import requests

url = "https://imdb236.p.rapidapi.com/api/imdb/cast/nm0000190/titles"
headers = {
	"x-rapidapi-key": "9424a30771msh2acd63cb7177f36p18a92djsn07b51a9b5029",
	"x-rapidapi-host": "imdb236.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

response.json()
# Out:
# [{'id': 'tt27706593',
#   'url': 'https://www.imdb.com/title/tt27706593/',
#   'primaryTitle': 'The Rivals of Amziah King',
#   'originalTitle': 'The Rivals of Amziah King',
#   'type': 'movie',
#   'description': 'Kateri loses her mother, leaves foster care. Reunites with former foster parent Amziah who mentors her, revealing hidden skills. Faces devastating situation, relies on newfound strength to seek justice.',
#   'primaryImage': 'https://m.media-amazon.com/images/M/MV5BODRhMTczNjgtMDcwNi00MDljLTkxN2ItYTFjOGJlMmIxY2U5XkEyXkFqcGc@.jpg',
#   'thumbnails': [{'url': 'https://m.media-amazon.com/images/M/MV5BODRhMTczNjgtMDcwNi00MDljLTkxN2ItYTFjOGJlMmIxY2U5XkEyXkFqcGc@._V1_QL75_UX100_CR0,0,100,148_.jpg',
#     'width': 100,
#     'height': 148},
#    {'url': 'https://m.media-amazon.com/images/M/MV5BODRhMTczNjgtMDcwNi00MDljLTkxN2ItYTFjOGJlMmIxY2U5XkEyXkFqcGc@._V1_QL75_UX280_CR0,0,280,414_.jpg',
#     'width': 280,
#     'height': 414},
# ...

# %%
df= pd.DataFrame(response.json())
df
# Out:
#             id                                     url  \
# 0   tt27706593  https://www.imdb.com/title/tt27706593/
# 1   tt21103218  https://www.imdb.com/title/tt21103218/
# 2   tt31937790  https://www.imdb.com/title/tt31937790/
# 3   tt27590028  https://www.imdb.com/title/tt27590028/
# 4   tt23219702  https://www.imdb.com/title/tt23219702/
# ..         ...                                     ...
# 95   tt0131369   https://www.imdb.com/title/tt0131369/
# 96   tt0287789   https://www.imdb.com/title/tt0287789/
# 97   tt0773260   https://www.imdb.com/title/tt0773260/
# 98   tt0120769   https://www.imdb.com/title/tt0120769/
# 99   tt0118884   https://www.imdb.com/title/tt0118884/
#
#                                   primaryTitle  \
# 0                    The Rivals of Amziah King
# 1                                 The Lost Bus
# 2    Superhuman Body: World of Medical Marvels
# 3                                   The Oscars
# 4                        2023 CMT Music Awards
# ...

# %%
df_new= pd.DataFrame(response.json())[['id','primaryTitle','originalTitle','type']].head(5)
df_new
# Out:
#            id                               primaryTitle  \
# 0  tt27706593                  The Rivals of Amziah King
# 1  tt21103218                               The Lost Bus
# 2  tt31937790  Superhuman Body: World of Medical Marvels
# 3  tt27590028                                 The Oscars
# 4  tt23219702                      2023 CMT Music Awards
#
#                                originalTitle       type
# 0                  The Rivals of Amziah King      movie
# 1                               The Lost Bus      movie
# 2  Superhuman Body: World of Medical Marvels      movie
# 3                                 The Oscars  tvSpecial
# 4                      2023 CMT Music Awards  tvSpecial

# %%
# multiple pages for loop .format(i) after url
