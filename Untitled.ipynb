# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\USER\ayush_1\a.csv")# index_col parameter
df
# Out:
#     ID     Name  Score
# 0    1    Alice     85
# 1    2      Bob     78
# 2    3  Charlie     92
# 3    4    David     88
# 4    5     Emma     90
# 5    6    Frank     75
# 6    7    Grace     95
# 7    8    Helen     82
# 8    9      Ian     79
# 9   10     Jack     91
# 10  11     Kate     87
# 11  12      Leo     80
# 12  13      Mia     89
# 13  14     Nina     93
# 14  15    Oscar     76

# %%
pd.read_csv(r"C:\Users\USER\ayush_1\a.csv",usecols=["Name"])
# Out:
#        Name
# 0     Alice
# 1       Bob
# 2   Charlie
# 3     David
# 4      Emma
# 5     Frank
# 6     Grace
# 7     Helen
# 8       Ian
# 9      Jack
# 10     Kate
# 11      Leo
# 12      Mia
# 13     Nina
# 14    Oscar

# %%
dfs = pd.read_csv(r"C:\Users\USER\ayush_1\a.csv",chunksize= 8)

# %%
for chunk in dfs:
    print(chunk.shape)
# Out:
# (8, 3)
# (7, 3)
